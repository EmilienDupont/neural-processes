# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
# %matplotlib inline

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Neural Process for 1D functions
#
# This notebook shows how to train and sample from a Neural Process for a simple class of 1D functions. The functions are defined by f(x) = a * sin(x - b) where a and b and randomly sampled.

# %% [markdown]
# ### Visualize Data

# %%
from datasets import SineData
from math import pi

# Create dataset
dataset = SineData(amplitude_range=(-1., 1.),
                   shift_range=(-.5, .5),
                   num_samples=2000)

# Visualize data samples
for i in range(64):
    x, y = dataset[i] 
    plt.plot(x.numpy(), y.numpy(), c='b', alpha=0.5)
    plt.xlim(-pi, pi)

# %% [markdown]
# ### Build Neural Process

# %%
from neural_process import NeuralProcess

x_dim = 1
y_dim = 1
r_dim = 50  # Dimension of representation of context points
z_dim = 50  # Dimension of sampled latent variable
h_dim = 50  # Dimension of hidden layers in encoder and decoder

neuralprocess = NeuralProcess(x_dim, y_dim, r_dim, z_dim, h_dim)

# %% [markdown]
# ### Visualize samples from prior
#
# We can visualize the prior (i.e. the output of the neural process without any context points) before training.

# %%
# Create a set of 100 target points, with shape 
# (batch_size, num_points, x_dim), which in this case is
# (1, 100, 1)
x_target = torch.Tensor(np.linspace(-pi, pi, 100))
x_target = x_target.unsqueeze(1).unsqueeze(0)

for i in range(64):
    z_sample = torch.randn((1, z_dim))  # Shape (batch_size, z_dim)
    # Map x_target and z to p_y_target (which is parameterized by a 
    # normal with mean mu and std dev sigma)
    mu, _ = neuralprocess.xz_to_y(x_target, z_sample)
    # Plot predicted mean at each target point (note we could also
    # sample from distribution but plot mean for simplicity)
    plt.plot(x_target.numpy()[0], mu.detach().numpy()[0], 
             c='b', alpha=0.5)
    plt.xlim(-pi, pi)

# %% [markdown]
# ### Train Neural Process

# %%
from torch.utils.data import DataLoader
from training import NeuralProcessTrainer

batch_size = 2
num_context = 4
num_target = 4

data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
optimizer = torch.optim.Adam(neuralprocess.parameters(), lr=3e-4)
np_trainer = NeuralProcessTrainer(device, neuralprocess, optimizer,
                                  num_context_range=(num_context, num_context),
                                  num_extra_target_range=(num_target, num_target), 
                                  print_freq=200)

neuralprocess.training = True
np_trainer.train(data_loader, 30)
# Out:
# iteration 200, loss 0.214
# iteration 400, loss 1.848
# iteration 600, loss -1.311
# iteration 800, loss 1.780
# iteration 1000, loss 3.320
# Epoch: 0, Avg_loss: 1.9148698284476995
# iteration 1200, loss 1.081
# iteration 1400, loss 4.900
# iteration 1600, loss -0.783
# iteration 1800, loss 2.554
# iteration 2000, loss 4.412
# Epoch: 1, Avg_loss: 1.3302350329309702
# iteration 2200, loss 1.312
# iteration 2400, loss -1.495
# iteration 2600, loss 3.347
# iteration 2800, loss 1.427
# iteration 3000, loss 2.515
# Epoch: 2, Avg_loss: 0.7284620865136385
# iteration 3200, loss 2.864
# iteration 3400, loss 1.340
# iteration 3600, loss -4.799
# iteration 3800, loss -0.110
# iteration 4000, loss -0.898
# Epoch: 3, Avg_loss: 0.08568483339250088
# iteration 4200, loss -0.324
# iteration 4400, loss -4.341
# iteration 4600, loss 1.621
# iteration 4800, loss -3.636
# iteration 5000, loss -0.871
# Epoch: 4, Avg_loss: -0.07209742447733879
# iteration 20600, loss -4.693
# iteration 20800, loss -4.017
# iteration 21000, loss -3.235
# Epoch: 20, Avg_loss: -3.7332886321544647
# iteration 21200, loss -1.383
# iteration 21400, loss -3.445
# iteration 21600, loss -3.332
# iteration 21800, loss -5.228
# iteration 22000, loss -5.116
# Epoch: 21, Avg_loss: -3.842019845187664
# iteration 22200, loss -4.960
# iteration 22400, loss -3.140
# iteration 22600, loss -4.245
# iteration 22800, loss -5.314
# iteration 23000, loss -1.926
# Epoch: 22, Avg_loss: -3.8210202552080155
# iteration 23200, loss -3.462
# iteration 23400, loss -3.711
# iteration 23600, loss -4.092
# iteration 23800, loss -4.840
# iteration 24000, loss -5.132
# Epoch: 23, Avg_loss: -3.8769992726147176
# iteration 24200, loss -1.961
# iteration 24400, loss -3.748
# iteration 24600, loss -1.910
# iteration 24800, loss 0.538
# iteration 25000, loss -4.236
# Epoch: 24, Avg_loss: -3.975677200913429
# iteration 25200, loss -1.121
# iteration 25400, loss -4.392
# iteration 25600, loss -3.769
# iteration 25800, loss -4.658
# iteration 26000, loss -4.300
# Epoch: 25, Avg_loss: -4.026671741664409
# iteration 26200, loss -4.428
# iteration 26400, loss -3.738
# iteration 26600, loss -4.304
# iteration 26800, loss -2.941
# iteration 27000, loss -5.359
# Epoch: 26, Avg_loss: -4.164043967306614
# iteration 27200, loss -1.537
# iteration 27400, loss -3.692
# iteration 27600, loss -3.792
# iteration 27800, loss -3.707
# iteration 28000, loss -4.939
# Epoch: 27, Avg_loss: -4.168327896952629
# iteration 28200, loss -4.989
# iteration 28400, loss -5.321
# iteration 28600, loss -4.492
# iteration 28800, loss -3.424
# iteration 29000, loss -4.887
# Epoch: 28, Avg_loss: -4.285344820141792
# iteration 29200, loss -4.886
# iteration 29400, loss -3.780
# iteration 29600, loss -4.777
# iteration 29800, loss -5.278
# iteration 30000, loss -4.764
# Epoch: 29, Avg_loss: -4.289010324716568

# %% [markdown]
# ### Visualize samples from trained prior
#
# The prior should now encode some information about the shapes of the functions.

# %%
x_target = torch.Tensor(np.linspace(-pi, pi, 100))
x_target = x_target.unsqueeze(1).unsqueeze(0)

for i in range(64):
    z_sample = torch.randn((1, z_dim))
    mu, _ = neuralprocess.xz_to_y(x_target, z_sample)
    plt.plot(x_target.numpy()[0], mu.detach().numpy()[0], 
             c='b', alpha=0.5)
    plt.xlim(-pi, pi)

# %% [markdown]
# ### Visualize samples from posterior

# %%
from utils import context_target_split

# Extract a batch from data_loader
for batch in data_loader:
    break

# Use batch to create random set of context points
x, y = batch
x_context, y_context, _, _ = context_target_split(x[0:1], y[0:1], 
                                                  num_context, 
                                                  num_target)

# Create a set of target points corresponding to entire [-pi, pi] range
x_target = torch.Tensor(np.linspace(-pi, pi, 100))
x_target = x_target.unsqueeze(1).unsqueeze(0)

neuralprocess.training = False

for i in range(64):
    # Neural process returns distribution over y_target
    p_y_pred = neuralprocess(x_context, y_context, x_target)
    # Extract mean of distribution
    mu = p_y_pred.loc.detach()
    plt.plot(x_target.numpy()[0], mu.numpy()[0], 
             alpha=0.05, c='b')

plt.scatter(x_context[0].numpy(), y_context[0].numpy(), c='k')
